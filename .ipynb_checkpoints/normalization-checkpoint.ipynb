# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import math

# %%
data = pd.read_csv('/Users/rachellecha/Desktop/UBS/no-score/UBSdata - 2018.csv')

# %%
for index, row in data.iterrows():
    if math.isnan(row["poverty"]):
        data.at[index, "poverty"] = 0
    if math.isnan(row["bachelors"]):
        data.at[index, "bachelors"] = 0
    if math.isnan(row["associates"]):
        data.at[index, "associates"] = 0
    if math.isnan(row["car"]):
        data.at[index, "car"] = 0
    if math.isnan(row["diff_countyHouse"]):
        data.at[index, "diff_countyHouse"] = 0
    if math.isnan(row["diff_countyRent"]):
        data.at[index, "diff_countyRent"] = 0
    if math.isnan(row["diff_stateHouse"]):
        data.at[index, "diff_stateHouse"] = 0
    if math.isnan(row["diff_stateRent"]):
        data.at[index, "diff_stateRent"] = 0
    if math.isnan(row["health_ins"]):
        data.at[index, "health_ins"] = 0
    if math.isnan(row["population"]):
        data.at[index, "population"] = 0
    if math.isnan(row["self_income"]):
        data.at[index, "self_income"] = 0
    if math.isnan(row["house_val"]):
        data.at[index, "house_val"] = 0

# %%
df2 = data[data.columns.difference(['full_name', 'census_tract'])]
normalized_df=(df2-df2.mean())/df2.std()

# %%
for index, row in normalized_df.iterrows():
    val = (row["poverty"]*0.12)+(row["bachelors"]*0.04)+(row["associates"]*0.07)+(row["car"]*0.08)+(row["diff_countyHouse"]*0.07)+(row["diff_countyRent"]*0.02)+(row["diff_stateRent"]*0.02)+(row["diff_stateHouse"]*0.07)+(row["health_ins"]*0.1)+(row["house_val"]*0.1)+(row["population"]*0.08)+(row["self_income"]*0.05)+(row["museums"]*0.08)+(row["pharmacies"]*0.1)
    normalized_df.at[index, "score"] = val

# %%
normalized_df["score"]=(normalized_df["score"]-normalized_df["score"].min())/(normalized_df["score"].max()-normalized_df["score"].min())*100

# %%
normalized_df.head(10)
# Out:
#    associates  bachelors       car  diff_countyHouse  diff_countyRent  \
# 0   -1.124448  -1.184470 -1.138599         -0.619780        -0.564730
# 1    0.070396  -0.318310  1.072695          1.396378        -0.718012
# 2    1.393259   0.447909  1.146762          0.013870         0.753498
# 3   -1.312210  -0.942945 -0.654476         -0.696586        -0.334806
# 4    2.016284   1.118351  1.993709         -0.696586         5.275326
# 5    0.667818   2.403017  1.246593         -0.427765         0.232338
# 6   -0.928153  -0.982505 -0.503657         -0.466168        -0.641371
# 7   -1.158587  -0.482797 -1.281903         -0.120541        -0.534073
# 8   -0.509957  -1.159485 -0.961481         -0.696586        -0.074227
# 9   -0.859876  -0.341213 -1.044136         -0.120541        -0.718012
#
#    diff_stateHouse  diff_stateRent  health_ins  house_val   museums  \
# 0        -0.558350        0.067856   -1.112696  -0.763971  0.312683
# 1        -0.691798       -0.408449    1.101662  -0.529140 -0.125641
# 2        -0.398213        1.169311    1.175742  -0.182118 -0.710074
# 3        -0.691798       -0.155412   -0.625806  -1.297428  1.335440
# 4        -0.344834        0.425084    2.022835  -0.024831 -0.417858
# 5         0.375781        0.439969    1.217614   1.944561  0.166575
# 6        -0.691798       -0.423333   -0.747662  -0.631982 -0.125641
# 7        -0.665108        0.216701   -1.253341  -0.208516 -0.710074
# 8        -0.211387        1.481886   -1.040226  -1.151140  1.335440
# 9        -0.264766       -0.572179   -1.015532   0.065912 -0.417858
#
#    pharmacies  population   poverty      score  self_income
# 0   -0.308789   -1.138599  0.844990  20.442249    -0.941716
# 1    1.764868    1.072695  1.804083  47.255084    -0.486864
# 2    0.579921    1.146762  0.481123  44.359773     0.278114
# 3   -0.308789   -0.654476  0.680934  22.801045    -1.262179
# 4    0.283684    1.993709  0.622042  52.720582     0.495202
# 5   -0.308789    1.246593 -0.597858  48.245123     1.394568
# 6    1.764868   -0.503657  1.318227  29.121382    -1.365554
# 7   -0.308789   -1.281903 -0.292883  16.974913    -1.045091
# 8   -1.197499   -0.961481  0.558944  21.099045    -1.510280
# 9    2.653578   -1.044136 -0.953311  25.567285    -0.993403

# %%
print(normalized_df['score'].min(), normalized_df['score'].max())
# Out:
# 0.0 100.0

# %%
normalized_df['full_name'] = pd.Series(data['full_name'])
normalized_df['census_tract'] = pd.Series(data['census_tract'])

normalized_df = normalized_df[['full_name', 'census_tract', 'associates', 'bachelors', "car", "diff_countyHouse", "diff_countyRent", "diff_stateHouse", "diff_stateRent", "health_ins", "house_val", "museums", "pharmacies", "population", "poverty", "self_income", "score"]]

# %%
normalized_df.head()
# Out:
#                                       full_name  census_tract  associates  \
# 0   Census Tract 1, Atlantic County, New Jersey           1.0   -1.124448
# 1      Census Tract 1, Essex County, New Jersey           1.0    0.070396
# 2     Census Tract 1, Hudson County, New Jersey           1.0    1.393259
# 3     Census Tract 1, Mercer County, New Jersey           1.0   -1.312210
# 4  Census Tract 1, Middlesex County, New Jersey           1.0    2.016284
#
#    bachelors       car  diff_countyHouse  diff_countyRent  diff_stateHouse  \
# 0  -1.184470 -1.138599         -0.619780        -0.564730        -0.558350
# 1  -0.318310  1.072695          1.396378        -0.718012        -0.691798
# 2   0.447909  1.146762          0.013870         0.753498        -0.398213
# 3  -0.942945 -0.654476         -0.696586        -0.334806        -0.691798
# 4   1.118351  1.993709         -0.696586         5.275326        -0.344834
#
#    diff_stateRent  health_ins  house_val   museums  pharmacies  population  \
# 0        0.067856   -1.112696  -0.763971  0.312683   -0.308789   -1.138599
# 1       -0.408449    1.101662  -0.529140 -0.125641    1.764868    1.072695
# 2        1.169311    1.175742  -0.182118 -0.710074    0.579921    1.146762
# 3       -0.155412   -0.625806  -1.297428  1.335440   -0.308789   -0.654476
# 4        0.425084    2.022835  -0.024831 -0.417858    0.283684    1.993709
#
#     poverty  self_income      score
# 0  0.844990    -0.941716  20.442249
# 1  1.804083    -0.486864  47.255084
# 2  0.481123     0.278114  44.359773
# 3  0.680934    -1.262179  22.801045
# 4  0.622042     0.495202  52.720582

# %%
normalized_df.to_csv(r'/Users/rachellecha/Desktop/UBS/extreme/2018-scores.csv', index = False)
